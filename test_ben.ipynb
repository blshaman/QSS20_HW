# %%
import string
import getpass
import urllib.request
import json
import sys
import operator
import os
import re
from datetime import datetime, timezone
from time import sleep
import pandas as pd

# %%
stream = ""
accessToken = ""

getChat = False
getCommentorStats = False
getImageLog = False
getVideoLog = False

# %%
#Setup to stage the execution of the program
def intro():
    global stream
    global accessToken
    global getChat
    global getCommentorStats
    global getImageLog
    global getVideoLog
    
    print("Hello, and welcome to the GroupMe Stats Extractor")
    print("If you do not already have an access token, please refer to the README")

    accessToken = getpass.getpass("Please Enter Your Access Token Now: ")
    
    print("Would you like to process a Group or a Direct Message stream?")
    while stream != 1 and stream != 2:
        stream = int(input("Enter 1 for Group, or 2 for Direct Message "))
        
    if stream == 1:
        stream = "groups"
    else:
        stream = "chats"

    allStream = []
    try:
        allStream = getAll(stream,accessToken)        
    except:
        print("\nError retrieving all " + stream + ".")
        print("Perhaps the access token was entered incorrectly.")
        print("Restarting Program...\n")
        intro()
        
    print("Which of the following " + stream + " would you like to analyze?")
    if stream == "chats":
        for  option in allStream:
            print(allStream.index(option) + 1,".\t",option["other_user"]["name"])
    elif stream == "groups":
        for option in allStream:
            print(allStream.index(option) + 1,".\t",option["name"])
   
    choice = input("Please enter your choice: ")
    while not choice.isdigit() and choice <= 0 and choice >= len(allStream):
        choice = input("Please enter a valid choice: ")
    choice = int(choice) - 1
   
    print("Which of the following would you like to enable (Please answer with 'y' or 'n'):")

    chatHistory = ""
    commentorStats = ""
    imageLog = ""
    videoLog = ""

    while len(chatHistory) < 1:
        chatHistory = input("Obtain Chat History? ")
    while len(commentorStats) < 1:
        commentorStats = input("Obtain Commentor Stats? ")
    while len(imageLog) < 1:
        imageLog = input("Obtain all Images? ")
    while len(videoLog) < 1:
        videoLog = input("Obtain all Videos? ")
    if chatHistory[0].lower() == "y":
        getChat = True
    if commentorStats[0].lower() == "y":
        getCommentorStats = True
    if imageLog[0].lower() == "y":
        getImageLog = True
    if videoLog[0].lower() == "y":
        getVideoLog = True


    if stream == "groups":
        return allStream[choice]["id"]
    elif stream == "chats":
        return allStream[choice]["other_user"]["id"]

# %%
#Obtains all groups/direct messages using paging
def getAll(choice, token):
    base = "https://api.groupme.com/v3"
    base += "/" + choice + "?token=" + token + "&per_page=100&omit=membership"

    jsonData = getRequest(base)
    response = jsonData["response"]

    temp = response
    k = 2
    
    while len(temp) > 0:
        link = base + "&page=" + str(k)
        temp = getRequest(link)["response"]
        response += temp
        k += 1
        link = base
        
    return response

# %%
#Returns the link used to make GET requests to construct the messagelog
def getLink(groupId):
    link = "https://api.groupme.com/v3"
    if stream == "groups":
        link += "/" + stream + "/" + groupId + "/" + "messages"
        link += "?token=" + accessToken + "&limit=100"
    elif stream == "chats":
        link += "/" + "direct_messages" + "?other_user_id=" + groupId
        link += "&token=" + accessToken + "&limit=100"
    return link

#Gets basic information about the chat. Used to obtain name and members
def getChatDetails(groupId):
    link = "https://api.groupme.com/v3"
    if stream == "groups":
        link += "/" + stream + "/" + groupId + "?token=" + accessToken
        chatInfo = getRequest(link)
        return (chatInfo["response"]["name"], chatInfo["response"]["members"])
    elif stream == "chats":
        chatInfo = getAll(stream,accessToken)
        for chat in chatInfo:
            if chat["other_user"]["id"] == groupId:
                return [chat["other_user"]["name"]]

# %%
#Leverages the URLlib to send a GET Request and maps out any forbidden characters
def getRequest(link):
    data = urllib.request.urlopen(link)
    non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)
    return json.loads(data.read().decode().translate(non_bmp_map))

#Sends GET messages to build up a dictionairy(JSON) of values
#Logs the console every 500 retreieved 
def buildMessageLog(link):
    base = link
    jsonData = getRequest(link)

    total = jsonData["response"]["count"]

    messages = []    
    if stream == "groups":
        messages = jsonData["response"]["messages"]
    elif stream == "chats":
        messages = jsonData["response"]["direct_messages"]
        
    while len(messages) < total:
        try:
            lastMessage = messages[len(messages) - 1]
            lastMessageId = lastMessage["id"]
            link += "&before_id=" + lastMessageId
            
            jsonData = getRequest(link)
            
            if stream == "groups":
                messages += jsonData["response"]["messages"]
            elif stream == "chats":
                messages += jsonData["response"]["direct_messages"]
            

            link = base
            if len(messages) % 500 == 0:
                print("Obtained " + str(len(messages)) + " thus far. "
                      + str(total - len(messages)) + " remain.")
        except:
            print("Error receiving first ", str(total-len(messages)),"messages")
            break
    return messages

# %%
#Creates an html file with chat history based on the message list
#File name is the name of the chat suffixed by the date
def record(chatDetails, messageList):
    print("Beginning to Create Chat Log")
    fileName = "Record-" + chatDetails[0] + "-" + str(datetime.now())[:10] +".html"
    htmlFile = open(fileName,"w",encoding="utf-8")

    htmlFile.write("""
    <html>
    <head>
      <link rel="stylesheet" href="style.css">
    </head>
      <body>
        <table>
          <tr>
            <th> Date </th>
            <th> Sender </th>
            <th> Message </th>
          </tr>
    """)
    history = ""
    for message in messageList:
        history += """
          <tr>
            <td>""" + str(timeStandard(message["created_at"])) + """</td>
            <td>""" + str(message["name"]) + """</td>
            <td>""" + str(message["text"]) + """</td>
          </tr>
          """
    htmlFile.write(history)
    htmlFile.write("""
        </table>
      </body>
    </html>
    """)
    htmlFile.close()
    print("Succesfully Created Chat Log. Refer to", fileName, "in the Root Directory.")

# %%
#Obtains various stats by parsing through the message list and scanning relevant IDs
def peopleStats(chatDetails, messageList):
    print("Beginning to Obtain All User Stats")
    
    commentCount = {}
    mentionCount = {}
    likeCount = {}
    likesGiven = {}
    selfLikes = {}
    nickname = {}

    if stream == "groups":
        for member in chatDetails[1]:
            nickname[member["user_id"]] = [member["nickname"]]
    
    for message in messageList:
        senderId = message["sender_id"]
        if senderId not in commentCount:
            commentCount[senderId] = 1
        elif senderId in commentCount:
            commentCount[senderId] += 1

        for attach in message["attachments"]:
            if len(attach) > 0 and attach["type"] == "mentions":
                for user in attach["user_ids"]:
                    if user not in mentionCount:
                        mentionCount[user] = 1
                    elif user in mentionCount:
                        mentionCount[user] += 1
                    
        if senderId not in likeCount:
            likeCount[senderId] = len(message["favorited_by"])
        elif senderId in likeCount:
            likeCount[senderId] += len(message["favorited_by"])

        for user in message["favorited_by"]:
            if user not in likesGiven:
                likesGiven[user] = 1
            elif user in likesGiven:
                likesGiven[user] += 1

            if senderId == user:
                if user not in selfLikes:
                    selfLikes[user] = 1
                elif user in selfLikes:
                    selfLikes[user] += 1
                    
        if senderId not in nickname:
            nickname[senderId] = []
        if message["name"] not in nickname[senderId]:
            nickname[senderId].append(message["name"])
    
    print("\n~~~~~~~~~~~~~~~~~TOTAL COMMENTS~~~~~~~~~~~~~~~\n")
    commentRanking = displayStats(nickname,commentCount)
    print("Total Comments: ", sum(commentRanking.values()))

    print("\n~~~~~~~~~~~~~~~~~TOTAL MENTIONS~~~~~~~~~~~~~~~\n")
    mentionRanking = displayStats(nickname,mentionCount)
    print("Total Mentions: ", sum(mentionRanking.values()))

    print("\n~~~~~~~~~~~~~~TOTAL LIKES RECEIVED~~~~~~~~~~~~\n")
    likeRanking = displayStats(nickname,likeCount)
    print("Total Likes: ", sum(likeRanking.values()))

    print("\n~~~~~~~~~~~~~~~TOTAL LIKES GIVEN~~~~~~~~~~~~~~\n")
    givenRanking = displayStats(nickname,likesGiven)
    print("Total Likes Given: ", sum(likesGiven.values()))

    print("\n~~~~~~~~~~~~~~~~TOTAL SELF LIKES~~~~~~~~~~~~~~\n")
    selfRanking = displayStats(nickname,selfLikes)
    print("Total Self Likes Given: ", sum(selfRanking.values()))
    
    print("\nFinished Displaying All User Stats")

# %%
#Obtains the images from users and avatar changes and renames them based on
#uploader and date
def obtainImages(messageList):
    print("Beginning to Obtain All Images")
    translator=str.maketrans('','',string.punctuation)
    for message in messageList:
        try:
            attachment = message["attachments"]
            if len(attachment) > 0:
                for attach in attachment:
                    if attach["type"] == "image":
                        picName = message["name"] + " "
                        picName = picName.translate(translator)
                        picName += timeStandard(message["created_at"]) + ".jpeg"
                        urllib.request.urlretrieve(attach["url"],picName)
            elif message["sender_id"] == "system":
                if "event" in message and len(message["event"]) > 0:
                    event = message["event"]
                    if event["type"] == "group.avatar_change":
                        picName = "Avatar Change " + event["data"]["user"]["nickname"] + " "
                        picName += timeStandard(message["created_at"])+ ".jpeg"
                        urllib.request.urlretrieve(event["data"]["avatar_url"],picName)
        except:
            errorMessage = "Error getting picture by " + message["name"]
            errorMessage += " at time " + timeStandard(message["created_at"])
            print(errorMessage)
    print("Obtaining Images Complete")

#Obtains all videos from chat and renames them based on uploader and date
def obtainVideos(messageList):
    print("Beginning to Obtain All Videos")
    regex = r"(https://v.groupme.com/.*\.mp4)"
    
    translator=str.maketrans('','',string.punctuation)
    
    
    for message in messageList:
        try:
            text = message["text"]
            if text and re.search(regex,text):
                vidName = message["name"] + " "
                vidName = vidName.translate(translator)
                vidName += timeStandard(message["created_at"]) + ".mp4"
                urllib.request.urlretrieve(re.search(regex,text).group(0),vidName)
        except:
            errorMessage = "Error getting video by " + message["name"]
            errorMessage += " at time " + timeStandard(message["created_at"])
            print(errorMessage)

            
    print("Obtaining Videos Complete")

# %%
##################Utility Functions######################

#Takes a dictionairy {userId:[nicknames]} and sorts them in desending order
def displayStats(nickname,statsDict):
    ranking = {}
    
    for user in statsDict:
        try:
            if len(nickname[user]) > 1 and len(nickname[user]) < 5:
                ranking[tuple(nickname[user])] = statsDict[user]
            else:
                ranking[nickname[user][0]] = statsDict[user]
        except:
            print("Error Logging User:", user)
        
    sortedRanking = sorted(ranking.items(),key = operator.itemgetter(1))

    for entry in sortedRanking[::-1]:
        print(entry)
        
    return ranking

#Used to convert time to a human readable value 
def timeStandard(epochTime):
    utcTime = datetime.fromtimestamp(epochTime, timezone.utc)
    
    return utcTime.astimezone().strftime("%m-%d-%Y %H-%M-%S")

# %%
def main():
    groupId = intro()
    link = getLink(groupId)
    print()
    allMessages = buildMessageLog(link)
    chatDetails = getChatDetails(groupId)
    print()
    if getChat:
        record(chatDetails, allMessages[::-1])
        print()
    if getCommentorStats:
        peopleStats(chatDetails, allMessages[::-1])
        print()
    if getImageLog:
        obtainImages(allMessages)
        print()
    if getVideoLog:
        obtainVideos(allMessages)
        print()
    print("Thank you for using GroupMe Stats!")
    
if __name__ == "__main__":
    main()
# Out:
# Hello, and welcome to the GroupMe Stats Extractor
# If you do not already have an access token, please refer to the README
# Please Enter Your Access Token Now: ········
# Would you like to process a Group or a Direct Message stream?
# Enter 1 for Group, or 2 for Direct Message 1
# Which of the following groups would you like to analyze?
# 1 .	 23FuckingShitflakes
# 2 .	 �� Sigma Nu RISK 23F ��
# 3 .	 points
# 4 .	 People Who Still Paddle
# 5 .	 Ledyard Canoe (and Kayak) Club
# 6 .	 Fahey McClane Floor 3 (23F)
# 7 .	 Ledyard Leaders
# 8 .	 das moüntain clüb
# 9 .	 The Dartmouth Climbing Gym
# 10 .	 Swifties of Dartmouth
# 11 .	 Dartmouth Cooking Club - Organizing Group
# 12 .	 Dartmouth Billiards Student Organization
# 13 .	 Within
# 14 .	 Ledyard Staff 23F
# 15 .	 People Who Paddle
# 16 .	 Nu Pingus Personnel
# 17 .	 23F Ledyard Leaders in Training
# 18 .	 Chabad 22-23
# 19 .	 Hillel 22-23
# 20 .	 Led Sub
# 21 .	 WET HOT LEDYARD SUMMER ���☀️
# 22 .	 Tender Love And Care Crew
# 23 .	 Ledyard Racing
# 24 .	 Ledyard IM Basketball
# 25 .	 Ledyard '26s New Member Groupme
# 26 .	 Français 1 Drill (avec Ben)
# 27 .	 west leb 9/09
# 28 .	 Westtown QMUNC
# 29 .	 JHUMUNC
# 30 .	 PMUNC
# Please enter your choice: 3
# Which of the following would you like to enable (Please answer with 'y' or 'n'):
# Obtain Chat History? y
# Obtain Commentor Stats? y
# Obtain all Images? n
# Obtain all Videos? n
#
# Obtained 500 thus far. 4213 remain.
# Obtained 1000 thus far. 3713 remain.
# Obtained 1500 thus far. 3213 remain.
# Obtained 2000 thus far. 2713 remain.
# Obtained 2500 thus far. 2213 remain.
# Obtained 3000 thus far. 1713 remain.
# Obtained 3500 thus far. 1213 remain.
# Obtained 4000 thus far. 713 remain.
# Obtained 4500 thus far. 213 remain.
#
# Beginning to Create Chat Log
# Succesfully Created Chat Log. Refer to Record-points-2023-11-01.html in the Root Directory.
#
# Beginning to Obtain All User Stats
#
# ~~~~~~~~~~~~~~~~~TOTAL COMMENTS~~~~~~~~~~~~~~~
#
# (('� �', 'Daniel Xu'), 454)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 333)
# (('Dexter Jandres Rivera', 'Dexter Jandres'), 316)
# ('Jeff Walbridge, Jr.', 244)
# (('Rishav', 'Rishav Chakravarty'), 224)
# ('Ben Sontag', 218)
# (('GroupMe', 'system'), 197)
# ('Josh Lee', 142)
# ('Tristan Wells', 139)
# ('Jack Macy', 138)
# ('Brandon', 115)
# ('Jack Van Hooser', 113)
# (('�\u200d⚖️', 'Andy Kotz', 'Yoink Sploink'), 111)
# ('Daniel Hernandez', 110)
# ('Jonathan Cartwright', 102)
# ('Benjamin Grayzel', 94)
# ('Emir Akat', 75)
# ('Trace Hilbun (he/they)', 69)
# ('Kai Goldstein', 67)
# ('Agastya Nashier', 65)
# ('Dominic Folkes', 58)
# ('Gannon Forsberg', 57)
# ('Sebastian Fernandez', 56)
# ('Christopher Smith', 54)
# ('Harrison Sholler', 51)
# ('Jason Sinning', 46)
# ('Kabir UK The Sequel', 45)
# ('Jack Flaggert', 43)
# ('Stephen Veatch', 41)
# ('Jack Sinatra', 39)
# ('Jesse Chan', 37)
# ('Cooper Hyldahl', 37)
# ('Daniel Lubliner', 37)
# ('Wenhan ☀️', 33)
# ('Ryan Gonzalez', 33)
# ('Stavros Hughes', 32)
# ('Caleb Saks', 31)
# ('Leon Wang', 30)
# ('Garrett Crouch', 28)
# ('Duncan Caramichael', 27)
# ('Dan Dong', 27)
# ('Anthony Cheng', 24)
# ('Josh Baxter', 24)
# ('Mason Carter', 23)
# ('Adam Hunt', 22)
# ('Trevor Geyer', 22)
# ('Sumant Sharma', 21)
# ('Allan Wang', 20)
# ('Jason Carenz', 20)
# ('Alex Hamel', 20)
# ('Ben Shaman', 19)
# ('Paulie Horvath', 19)
# ('Michael Bornstein', 19)
# ('Rohan Goyal', 18)
# ('Paul Cornell', 17)
# ('Tristan Kunzle', 16)
# ('Ethan Lieberman', 16)
# ('Jacob Kingsley', 15)
# ('Tobin Yates', 15)
# ('Jackson Yassin', 15)
# ('Ryker Holsinger', 13)
# ('Ethan Child', 13)
# ('jacob gordon', 12)
# ('Jake Zikan', 12)
# ('Jaime Graft', 10)
# ('Prescott Herzog', 10)
# ('Olvin Abrego', 10)
# ('Max Breuninger', 9)
# ('Johan', 8)
# ('Devin Tsai', 8)
# ('Samuel Dupuis', 7)
# ('Wesley Liao', 7)
# ('Lukas Hoffman', 6)
# ('Chase Kamikawa', 6)
# ('Zachary Seburn', 6)
# ('Hayden Miller', 6)
# ('William Perez', 5)
# ('Sam Zuniga', 5)
# ('Miles', 5)
# ('Gavan Fink', 5)
# ('Shyam Bhagat', 4)
# ('Isaac Schildkraut', 4)
# ('Justin Chong', 3)
# ('Krishnachandra Nair', 2)
# ('Lucas DiSilvestro', 2)
# ('Angus Yip', 2)
# Total Comments:  4713
#
# ~~~~~~~~~~~~~~~~~TOTAL MENTIONS~~~~~~~~~~~~~~~
#
# Error Logging User: -1
# Error Logging User: 44550017
# ('Josh Lee', 270)
# ('Daniel Hernandez', 118)
# ('Brandon', 110)
# ('Agastya Nashier', 88)
# ('Ryan Gonzalez', 81)
# ('Caleb Saks', 75)
# ('Garrett Crouch', 61)
# ('Paulie Horvath', 60)
# ('Kabir UK The Sequel', 53)
# ('Kai Goldstein', 53)
# ('Jesse Chan', 51)
# ('Leon Wang', 51)
# ('Cooper Hyldahl', 50)
# ('jacob gordon', 50)
# ('Jackson Yassin', 48)
# ('Ben Shaman', 48)
# ('Rohan Goyal', 48)
# ('Tobin Yates', 45)
# ('Emir Akat', 42)
# ('Ethan Child', 41)
# ('Samuel Dupuis', 37)
# ('Sumant Sharma', 37)
# ('Jack Flaggert', 36)
# ('Adam Hunt', 34)
# ('Ethan Lieberman', 33)
# ('Miles', 32)
# ('Chase Kamikawa', 30)
# ('Trevor Geyer', 29)
# (('Rishav', 'Rishav Chakravarty'), 28)
# ('Ryker Holsinger', 27)
# ('Gavan Fink', 25)
# ('Zachary Seburn', 24)
# ('Shyam Bhagat', 20)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 13)
# ('Ben Sontag', 13)
# ('Jack Macy', 11)
# (('� �', 'Daniel Xu'), 10)
# ('Jeff Walbridge, Jr.', 9)
# (('�\u200d⚖️', 'Andy Kotz', 'Yoink Sploink'), 8)
# ('Jack Van Hooser', 8)
# ('Christopher Smith', 7)
# ('Dan Dong', 6)
# (('Dexter Jandres Rivera', 'Dexter Jandres'), 6)
# ('Jonathan Cartwright', 6)
# ('Stavros Hughes', 5)
# ('Tristan Wells', 4)
# ('Harrison Sholler', 4)
# ('Trace Hilbun (he/they)', 4)
# ('Jason Sinning', 3)
# ('Daniel Lubliner', 3)
# ('Devin Tsai', 3)
# ('Michael Bornstein', 3)
# ('Stephen Veatch', 3)
# ('Jason Carenz', 2)
# ('Mason Carter', 2)
# ('Paul Cornell', 2)
# ('Sebastian Fernandez', 2)
# ('Allan Wang', 2)
# ('Benjamin Grayzel', 2)
# ('Josh Baxter', 2)
# ('Jack Sinatra', 2)
# ('Duncan Caramichael', 1)
# ('Noah da Silva', 1)
# ('Wenhan ☀️', 1)
# ('Wesley Liao', 1)
# ('Tristan Kunzle', 1)
# ('Max Breuninger', 1)
# ('Johan', 1)
# Total Mentions:  1987
#
# ~~~~~~~~~~~~~~TOTAL LIKES RECEIVED~~~~~~~~~~~~
#
# ('Josh Lee', 418)
# (('� �', 'Daniel Xu'), 391)
# (('Dexter Jandres Rivera', 'Dexter Jandres'), 372)
# ('Tristan Wells', 267)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 267)
# ('Ben Sontag', 258)
# (('Rishav', 'Rishav Chakravarty'), 231)
# ('Jeff Walbridge, Jr.', 227)
# (('�\u200d⚖️', 'Andy Kotz', 'Yoink Sploink'), 196)
# ('Jesse Chan', 186)
# ('Brandon', 175)
# ('Jack Macy', 144)
# ('Sebastian Fernandez', 137)
# ('Daniel Lubliner', 135)
# ('Agastya Nashier', 115)
# ('Jack Van Hooser', 110)
# ('Jonathan Cartwright', 108)
# ('Trevor Geyer', 99)
# ('Emir Akat', 94)
# ('Dominic Folkes', 94)
# ('Benjamin Grayzel', 81)
# ('Christopher Smith', 78)
# ('Daniel Hernandez', 71)
# ('Trace Hilbun (he/they)', 68)
# ('Cooper Hyldahl', 68)
# ('Dan Dong', 63)
# ('Kai Goldstein', 62)
# ('Ben Shaman', 60)
# ('Jackson Yassin', 60)
# ('Stephen Veatch', 59)
# ('Harrison Sholler', 57)
# ('Jack Sinatra', 53)
# ('Kabir UK The Sequel', 50)
# ('Gannon Forsberg', 49)
# ('Paulie Horvath', 45)
# ('Jason Sinning', 42)
# ('Adam Hunt', 41)
# ('Stavros Hughes', 35)
# ('Caleb Saks', 35)
# ('Jason Carenz', 34)
# ('Wenhan ☀️', 32)
# ('Michael Bornstein', 31)
# ('Ryan Gonzalez', 31)
# ('Jack Flaggert', 27)
# ('Sumant Sharma', 26)
# ('Garrett Crouch', 26)
# ('Mason Carter', 25)
# ('Tristan Kunzle', 24)
# ('Ethan Lieberman', 24)
# ('Paul Cornell', 23)
# (('GroupMe', 'system'), 23)
# ('Zachary Seburn', 22)
# ('Josh Baxter', 22)
# ('Ethan Child', 22)
# ('jacob gordon', 21)
# ('Jake Zikan', 21)
# ('Ryker Holsinger', 21)
# ('Tobin Yates', 19)
# ('Duncan Caramichael', 18)
# ('Prescott Herzog', 17)
# ('Jacob Kingsley', 15)
# ('Leon Wang', 12)
# ('Samuel Dupuis', 11)
# ('Wesley Liao', 11)
# ('Lukas Hoffman', 10)
# ('Olvin Abrego', 10)
# ('Alex Hamel', 10)
# ('Max Breuninger', 9)
# ('Jaime Graft', 9)
# ('Rohan Goyal', 9)
# ('Johan', 7)
# ('Miles', 7)
# ('Shyam Bhagat', 7)
# ('Lucas DiSilvestro', 6)
# ('Anthony Cheng', 6)
# ('Chase Kamikawa', 5)
# ('Allan Wang', 5)
# ('Hayden Miller', 4)
# ('Angus Yip', 3)
# ('Isaac Schildkraut', 3)
# ('Devin Tsai', 3)
# ('Justin Chong', 2)
# ('Sam Zuniga', 1)
# ('Gavan Fink', 1)
# ('Krishnachandra Nair', 0)
# ('William Perez', 0)
# Total Likes:  5776
#
# ~~~~~~~~~~~~~~~TOTAL LIKES GIVEN~~~~~~~~~~~~~~
#
# Error Logging User: 44550017
# (('Rishav', 'Rishav Chakravarty'), 536)
# ('Jack Macy', 318)
# (('� �', 'Daniel Xu'), 302)
# ('Daniel Hernandez', 285)
# ('Sebastian Fernandez', 244)
# (('�\u200d⚖️', 'Andy Kotz', 'Yoink Sploink'), 241)
# ('Tristan Wells', 222)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 179)
# ('Ben Sontag', 164)
# ('Stephen Veatch', 150)
# ('Jesse Chan', 149)
# ('Garrett Crouch', 142)
# ('Caleb Saks', 130)
# ('Agastya Nashier', 128)
# ('Jack Van Hooser', 128)
# ('Jonathan Cartwright', 104)
# ('Kabir UK The Sequel', 100)
# ('Josh Lee', 96)
# ('Sumant Sharma', 93)
# ('Brandon', 93)
# ('Gannon Forsberg', 91)
# ('Christopher Smith', 84)
# ('Ethan Child', 82)
# ('jacob gordon', 75)
# ('Shyam Bhagat', 74)
# ('Duncan Caramichael', 72)
# ('Leon Wang', 72)
# ('Benjamin Grayzel', 63)
# ('Samuel Dupuis', 59)
# ('Jason Carenz', 56)
# ('Trace Hilbun (he/they)', 56)
# ('Jack Flaggert', 55)
# ('Ethan Lieberman', 54)
# ('Wenhan ☀️', 49)
# ('Jack Sinatra', 47)
# ('Zachary Seburn', 46)
# ('Harrison Sholler', 42)
# ('Paulie Horvath', 39)
# ('Cooper Hyldahl', 39)
# ('Jeff Walbridge, Jr.', 38)
# ('Kai Goldstein', 35)
# (('Dexter Jandres Rivera', 'Dexter Jandres'), 34)
# ('Stavros Hughes', 33)
# ('Krishnachandra Nair', 33)
# ('Rohan Goyal', 33)
# ('Dominic Folkes', 32)
# ('Dan Dong', 31)
# ('Ryan Gonzalez', 31)
# ('Trevor Geyer', 30)
# ('Emir Akat', 30)
# ('Michael Bornstein', 30)
# ('Jake Zikan', 29)
# ('Gavan Fink', 28)
# ('Mason Carter', 26)
# ('Josh Baxter', 24)
# ('Jacob Kingsley', 23)
# ('Adam Hunt', 23)
# ('Prescott Herzog', 21)
# ('Ryker Holsinger', 21)
# ('Alex Hamel', 20)
# ('Chase Kamikawa', 18)
# ('Olvin Abrego', 16)
# ('Ben Shaman', 16)
# ('Tobin Yates', 14)
# ('Miles', 14)
# ('Jason Sinning', 14)
# ('Paul Cornell', 13)
# ('Jaime Graft', 12)
# ('Lukas Hoffman', 11)
# ('Daniel Lubliner', 11)
# ('Tristan Kunzle', 10)
# ('Jackson Yassin', 10)
# ('Hayden Miller', 8)
# ('Wesley Liao', 7)
# ('Noah da Silva', 7)
# ('Max Breuninger', 6)
# ('Allan Wang', 6)
# ('Angus Yip', 4)
# ('Justin Chong', 3)
# ('Anthony Cheng', 1)
# ('William Perez', 1)
# ('Lucas DiSilvestro', 1)
# ('Isaac Schildkraut', 1)
# Total Likes Given:  5776
#
# ~~~~~~~~~~~~~~~~TOTAL SELF LIKES~~~~~~~~~~~~~~
#
# (('�\u200d⚖️', 'Andy Kotz', 'Yoink Sploink'), 3)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 2)
# ('Sebastian Fernandez', 2)
# ('Christopher Smith', 1)
# ('Emir Akat', 1)
# (('Dexter Jandres Rivera', 'Dexter Jandres'), 1)
# ('Kai Goldstein', 1)
# ('Agastya Nashier', 1)
# Total Self Likes Given:  12
#
# Finished Displaying All User Stats
#
# Thank you for using GroupMe Stats!

# %%
## Analysis
# brothers = ["Jonathan Cartwright",
#            "Andy Kotz",
#            "Daniel Xu",
#            "Jason Sinning",
#            "Alex Hamel",
#            "Anthony Cheng",
#            "Ben Sontag",
#            "Benjamin Grayzel",
#            "Christopher Smith",
#            "Dan Dong",
#            "Daniel Lubliner",
#            "Devin Tsai",
#            "Dexter Jandres",
#            "Dominic Folkes",
#            "Harrison Sholler",
#            "Hayden Miller",
#            "Isaac Schildkraut",
#            "Jack Macy",
#            "Jack Sinatra",
#            "Jack Van Hooser",
#            "Jake Zikan",
#            "Jason Carenz",
#            "Jeff Walbridge, Jr.",
#            "Josh Baxter",
#            "Krishnachandra Nair",
#            "Michael Bornstein",
#            "Olvin Abrego",
#            "Paul Cornell",
#            "Rishav Chakravarty",
#            "Sebastian Fernandez",
#            "Stephen Veatch",
#            "Syed Hussaini",
#            "Tristan Kunzle",
#            "Tristan Wells",
#            "Wenhan ☀️",
#            "Wesley Liao",
#            "james mosley",
#            "Angus Yip",
#            "Gannon Forsberg"]

df = pd.read_html("Record-points-2023-11-01.html")
df = pd.DataFrame(df[0])
df = df.drop(columns = "Date")


## Filter to relevant messages
filt = df[df["Message"].str.contains(r"^(\+\d+|\-\d+)\s\@(\S+\s?[A-Z]?)") &  
          ~df["Message"].str.contains(r"\@Ben\sSontag", na = False)]


regex = r"\@(\S+\s?[A-Z]?)"

mentions = [re.findall(regex, x) for x in filt.Message]
for lst in range(len(mentions)):
    for seq in range(len(mentions[lst])):
        mentions[lst][seq] = mentions[lst][seq].strip()


filt["mention"] = mentions
filt

regex2 = r"\+\d+|\-\d+"
points = [re.findall(regex2, x) for x in filt.Message]
points

filt["points"] = points

people = [len(x) for x in filt.mention]
points_prob = [len(x) for x in filt.points]

filt["people"] = people
filt["points_prob"] = points_prob

problem_cases = filt[(filt["people"] != 1) | (filt["points_prob"] != 1)]

points_as_numbers = [int(x[0]) for x in filt.points]

filt["points_as_numbers"] = points_as_numbers
filt = filt[(filt["points_as_numbers"] <= 10000) & (filt["points_as_numbers"] >= -10000)]

filt = filt.explode("mention")
by_person_sender = filt.groupby("mention")[["points_as_numbers", "Sender"]].agg(sum)
by_person = filt.groupby("mention")["points_as_numbers"].agg(sum)
# Out:
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:48: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filt = df[df["Message"].str.contains(r"^(\+\d+|\-\d+)\s\@(\S+\s?[A-Z]?)") &
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["mention"] = mentions
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points"] = points
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["people"] = people
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points_prob"] = points_prob
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points_as_numbers"] = points_as_numbers
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:83: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   by_person_sender = filt.groupby("mention")[["points_as_numbers", "Sender"]].agg(sum)
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_10448/718357546.py:84: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   by_person = filt.groupby("mention")["points_as_numbers"].agg(sum)

# %%
irrelevant = ["Rishav C",
             "Jonathan C",
             "Jeff W",
             "Jack V",
             "s",
             "Andy K",
             "Syed H",
             "Daniel X",
             "Stephen V",
             "josh",
             "Jack M",
             "dartmouth",
             "ï¿½",
             "ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½",
             "josh L",
             "Trace H",
             "Dan D",
             "dexter,",
             "shitflakes",
             "Josh B",
             "Dexter J",
             "Miles M",
             "Benjamin G",
             "Allan W",
             "Daniel L",
             "pledges",
             "Sebastian F",
             "Brandon I",
             "Christopher S",
             "Paul C",
             "Johan",
             "Michael B",
             "Harrison S",
             "Jason C",
             "Devin T",
             "Jordan S",
             "everybody I",
             "pierre B",
             "Stavros H",
             "daniel",
             "Jack S",
             "josh F",
             "myself",
             "everyone",
             "Tomas B",
             "jack M",
             "Jason S",
             "Duncan C",
             "Noah",
             "Wenhan",
             "ï¿½ââï¸",
             "Tristan W"]

by_person = by_person.reset_index()
by_person = by_person[~by_person["mention"].isin(irrelevant)].sort_values(by = "points_as_numbers")
by_person
# Out:
#     index       mention  points_as_numbers
# 0      57      Sumant S              -2570
# 1       1     Agastya N               -970
# 2      40         Kai G               -433
# 3      23       Gavan F               -410
# 4      43         Miles               -400
# 5      49       Rohan G                -90
# 6      54       Shyam B                -85
# 7      81  ï¿½ââï¸                100
# 8      19        Emir A                160
# 9      22     Garrett C                163
# 10     41        Leon W                173
# 11      8       Caleb S                182
# 12      6       Brandon                186
# 13     13      Daniel H                837
# 14     52      Samuel D               1627
# 15     59       Tobin Y               1725
# 16     65     Zachary S               1734
# 17      9       Chase K               1977
# 18     20       Ethan C               1988
# 19     21       Ethan L               1991
# 20     51       Ryker H               2094
# 21     29     Jackson Y               2302
# 22     11      Cooper H               2453
# 23     62      Trevor G               2495
# 24      0        Adam H               2535
# 25     33       Jesse C               2769
# 26     25        Jack F               2797
# 27      4         Ben S               2805
# 28     71         jacob               2869
# 29     50        Ryan G               3057
# 30     39       Kabir U               3519
# 31     47      Paulie H               4075
# 32     38        Josh L              17246
