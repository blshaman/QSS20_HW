# %%
import string
import getpass
import urllib.request
import json
import sys
import operator
import os
import re
from datetime import datetime, timezone
from time import sleep
import pandas as pd

# %%
stream = ""
accessToken = ""

getChat = False
getCommentorStats = False
getImageLog = False
getVideoLog = False

# %%
#Setup to stage the execution of the program
def intro():
    global stream
    global accessToken
    global getChat
    global getCommentorStats
    global getImageLog
    global getVideoLog
    
    print("Hello, and welcome to the GroupMe Stats Extractor")
    print("If you do not already have an access token, please refer to the README")

    accessToken = getpass.getpass("Please Enter Your Access Token Now: ")
    
    print("Would you like to process a Group or a Direct Message stream?")
    while stream != 1 and stream != 2:
        stream = int(input("Enter 1 for Group, or 2 for Direct Message "))
        
    if stream == 1:
        stream = "groups"
    else:
        stream = "chats"

    allStream = []
    try:
        allStream = getAll(stream,accessToken)        
    except:
        print("\nError retrieving all " + stream + ".")
        print("Perhaps the access token was entered incorrectly.")
        print("Restarting Program...\n")
        intro()
        
    print("Which of the following " + stream + " would you like to analyze?")
    if stream == "chats":
        for  option in allStream:
            print(allStream.index(option) + 1,".\t",option["other_user"]["name"])
    elif stream == "groups":
        for option in allStream:
            print(allStream.index(option) + 1,".\t",option["name"])
   
    choice = input("Please enter your choice: ")
    while not choice.isdigit() and choice <= 0 and choice >= len(allStream):
        choice = input("Please enter a valid choice: ")
    choice = int(choice) - 1
   
    print("Which of the following would you like to enable (Please answer with 'y' or 'n'):")

    chatHistory = ""
    commentorStats = ""
    imageLog = ""
    videoLog = ""

    while len(chatHistory) < 1:
        chatHistory = input("Obtain Chat History? ")
    while len(commentorStats) < 1:
        commentorStats = input("Obtain Commentor Stats? ")
    while len(imageLog) < 1:
        imageLog = input("Obtain all Images? ")
    while len(videoLog) < 1:
        videoLog = input("Obtain all Videos? ")
    if chatHistory[0].lower() == "y":
        getChat = True
    if commentorStats[0].lower() == "y":
        getCommentorStats = True
    if imageLog[0].lower() == "y":
        getImageLog = True
    if videoLog[0].lower() == "y":
        getVideoLog = True


    if stream == "groups":
        return allStream[choice]["id"]
    elif stream == "chats":
        return allStream[choice]["other_user"]["id"]

# %%
#Obtains all groups/direct messages using paging
def getAll(choice, token):
    base = "https://api.groupme.com/v3"
    base += "/" + choice + "?token=" + token + "&per_page=100&omit=membership"

    jsonData = getRequest(base)
    response = jsonData["response"]

    temp = response
    k = 2
    
    while len(temp) > 0:
        link = base + "&page=" + str(k)
        temp = getRequest(link)["response"]
        response += temp
        k += 1
        link = base
        
    return response

# %%
#Returns the link used to make GET requests to construct the messagelog
def getLink(groupId):
    link = "https://api.groupme.com/v3"
    if stream == "groups":
        link += "/" + stream + "/" + groupId + "/" + "messages"
        link += "?token=" + accessToken + "&limit=100"
    elif stream == "chats":
        link += "/" + "direct_messages" + "?other_user_id=" + groupId
        link += "&token=" + accessToken + "&limit=100"
    return link

#Gets basic information about the chat. Used to obtain name and members
def getChatDetails(groupId):
    link = "https://api.groupme.com/v3"
    if stream == "groups":
        link += "/" + stream + "/" + groupId + "?token=" + accessToken
        chatInfo = getRequest(link)
        return (chatInfo["response"]["name"], chatInfo["response"]["members"])
    elif stream == "chats":
        chatInfo = getAll(stream,accessToken)
        for chat in chatInfo:
            if chat["other_user"]["id"] == groupId:
                return [chat["other_user"]["name"]]

# %%
#Leverages the URLlib to send a GET Request and maps out any forbidden characters
def getRequest(link):
    data = urllib.request.urlopen(link)
    non_bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)
    return json.loads(data.read().decode().translate(non_bmp_map))

#Sends GET messages to build up a dictionairy(JSON) of values
#Logs the console every 500 retreieved 
def buildMessageLog(link):
    base = link
    jsonData = getRequest(link)

    total = jsonData["response"]["count"]

    messages = []    
    if stream == "groups":
        messages = jsonData["response"]["messages"]
    elif stream == "chats":
        messages = jsonData["response"]["direct_messages"]
        
    while len(messages) < total:
        try:
            lastMessage = messages[len(messages) - 1]
            lastMessageId = lastMessage["id"]
            link += "&before_id=" + lastMessageId
            
            jsonData = getRequest(link)
            
            if stream == "groups":
                messages += jsonData["response"]["messages"]
            elif stream == "chats":
                messages += jsonData["response"]["direct_messages"]
            

            link = base
            if len(messages) % 500 == 0:
                print("Obtained " + str(len(messages)) + " thus far. "
                      + str(total - len(messages)) + " remain.")
        except:
            print("Error receiving first ", str(total-len(messages)),"messages")
            break
    return messages

# %%
#Creates an html file with chat history based on the message list
#File name is the name of the chat suffixed by the date
def record(chatDetails, messageList):
    print("Beginning to Create Chat Log")
    fileName = "Record-" + chatDetails[0] + "-" + str(datetime.now())[:10] +".html"
    htmlFile = open(fileName,"w",encoding="utf-8")

    htmlFile.write("""
    <html>
    <head>
      <link rel="stylesheet" href="style.css">
    </head>
      <body>
        <table>
          <tr>
            <th> Date </th>
            <th> Sender </th>
            <th> Message </th>
          </tr>
    """)
    history = ""
    for message in messageList:
        history += """
          <tr>
            <td>""" + str(timeStandard(message["created_at"])) + """</td>
            <td>""" + str(message["name"]) + """</td>
            <td>""" + str(message["text"]) + """</td>
          </tr>
          """
    htmlFile.write(history)
    htmlFile.write("""
        </table>
      </body>
    </html>
    """)
    htmlFile.close()
    print("Succesfully Created Chat Log. Refer to", fileName, "in the Root Directory.")

# %%
#Obtains various stats by parsing through the message list and scanning relevant IDs
def peopleStats(chatDetails, messageList):
    print("Beginning to Obtain All User Stats")
    
    commentCount = {}
    mentionCount = {}
    likeCount = {}
    likesGiven = {}
    selfLikes = {}
    nickname = {}

    if stream == "groups":
        for member in chatDetails[1]:
            nickname[member["user_id"]] = [member["nickname"]]
    
    for message in messageList:
        senderId = message["sender_id"]
        if senderId not in commentCount:
            commentCount[senderId] = 1
        elif senderId in commentCount:
            commentCount[senderId] += 1

        for attach in message["attachments"]:
            if len(attach) > 0 and attach["type"] == "mentions":
                for user in attach["user_ids"]:
                    if user not in mentionCount:
                        mentionCount[user] = 1
                    elif user in mentionCount:
                        mentionCount[user] += 1
                    
        if senderId not in likeCount:
            likeCount[senderId] = len(message["favorited_by"])
        elif senderId in likeCount:
            likeCount[senderId] += len(message["favorited_by"])

        for user in message["favorited_by"]:
            if user not in likesGiven:
                likesGiven[user] = 1
            elif user in likesGiven:
                likesGiven[user] += 1

            if senderId == user:
                if user not in selfLikes:
                    selfLikes[user] = 1
                elif user in selfLikes:
                    selfLikes[user] += 1
                    
        if senderId not in nickname:
            nickname[senderId] = []
        if message["name"] not in nickname[senderId]:
            nickname[senderId].append(message["name"])
    
    print("\n~~~~~~~~~~~~~~~~~TOTAL COMMENTS~~~~~~~~~~~~~~~\n")
    commentRanking = displayStats(nickname,commentCount)
    print("Total Comments: ", sum(commentRanking.values()))

    print("\n~~~~~~~~~~~~~~~~~TOTAL MENTIONS~~~~~~~~~~~~~~~\n")
    mentionRanking = displayStats(nickname,mentionCount)
    print("Total Mentions: ", sum(mentionRanking.values()))

    print("\n~~~~~~~~~~~~~~TOTAL LIKES RECEIVED~~~~~~~~~~~~\n")
    likeRanking = displayStats(nickname,likeCount)
    print("Total Likes: ", sum(likeRanking.values()))

    print("\n~~~~~~~~~~~~~~~TOTAL LIKES GIVEN~~~~~~~~~~~~~~\n")
    givenRanking = displayStats(nickname,likesGiven)
    print("Total Likes Given: ", sum(likesGiven.values()))

    print("\n~~~~~~~~~~~~~~~~TOTAL SELF LIKES~~~~~~~~~~~~~~\n")
    selfRanking = displayStats(nickname,selfLikes)
    print("Total Self Likes Given: ", sum(selfRanking.values()))
    
    print("\nFinished Displaying All User Stats")

# %%
#Obtains the images from users and avatar changes and renames them based on
#uploader and date
def obtainImages(messageList):
    print("Beginning to Obtain All Images")
    translator=str.maketrans('','',string.punctuation)
    for message in messageList:
        try:
            attachment = message["attachments"]
            if len(attachment) > 0:
                for attach in attachment:
                    if attach["type"] == "image":
                        picName = message["name"] + " "
                        picName = picName.translate(translator)
                        picName += timeStandard(message["created_at"]) + ".jpeg"
                        urllib.request.urlretrieve(attach["url"],picName)
            elif message["sender_id"] == "system":
                if "event" in message and len(message["event"]) > 0:
                    event = message["event"]
                    if event["type"] == "group.avatar_change":
                        picName = "Avatar Change " + event["data"]["user"]["nickname"] + " "
                        picName += timeStandard(message["created_at"])+ ".jpeg"
                        urllib.request.urlretrieve(event["data"]["avatar_url"],picName)
        except:
            errorMessage = "Error getting picture by " + message["name"]
            errorMessage += " at time " + timeStandard(message["created_at"])
            print(errorMessage)
    print("Obtaining Images Complete")

#Obtains all videos from chat and renames them based on uploader and date
def obtainVideos(messageList):
    print("Beginning to Obtain All Videos")
    regex = r"(https://v.groupme.com/.*\.mp4)"
    
    translator=str.maketrans('','',string.punctuation)
    
    
    for message in messageList:
        try:
            text = message["text"]
            if text and re.search(regex,text):
                vidName = message["name"] + " "
                vidName = vidName.translate(translator)
                vidName += timeStandard(message["created_at"]) + ".mp4"
                urllib.request.urlretrieve(re.search(regex,text).group(0),vidName)
        except:
            errorMessage = "Error getting video by " + message["name"]
            errorMessage += " at time " + timeStandard(message["created_at"])
            print(errorMessage)

            
    print("Obtaining Videos Complete")

# %%
##################Utility Functions######################

#Takes a dictionairy {userId:[nicknames]} and sorts them in desending order
def displayStats(nickname,statsDict):
    ranking = {}
    
    for user in statsDict:
        try:
            if len(nickname[user]) > 1 and len(nickname[user]) < 5:
                ranking[tuple(nickname[user])] = statsDict[user]
            else:
                ranking[nickname[user][0]] = statsDict[user]
        except:
            print("Error Logging User:", user)
        
    sortedRanking = sorted(ranking.items(),key = operator.itemgetter(1))

    for entry in sortedRanking[::-1]:
        print(entry)
        
    return ranking

#Used to convert time to a human readable value 
def timeStandard(epochTime):
    utcTime = datetime.fromtimestamp(epochTime, timezone.utc)
    
    return utcTime.astimezone().strftime("%m-%d-%Y %H-%M-%S")

# %%
def main():
    groupId = intro()
    link = getLink(groupId)
    print()
    allMessages = buildMessageLog(link)
    chatDetails = getChatDetails(groupId)
    print()
    if getChat:
        record(chatDetails, allMessages[::-1])
        print()
    if getCommentorStats:
        peopleStats(chatDetails, allMessages[::-1])
        print()
    if getImageLog:
        obtainImages(allMessages)
        print()
    if getVideoLog:
        obtainVideos(allMessages)
        print()
    print("Thank you for using GroupMe Stats!")
    
if __name__ == "__main__":
    main()
# Out:
# Hello, and welcome to the GroupMe Stats Extractor
# If you do not already have an access token, please refer to the README
# Please Enter Your Access Token Now: ········
# Would you like to process a Group or a Direct Message stream?
# Enter 1 for Group, or 2 for Direct Message 1
# Which of the following groups would you like to analyze?
# 1 .	 points
# 2 .	 The Dartmouth Climbing Gym
# 3 .	 das moüntain clüb
# 4 .	 People Who Still Paddle
# 5 .	 �� Sigma Nu RISK 23F ��
# 6 .	 Ledyard Canoe (and Kayak) Club
# 7 .	 Ledyard Staff 23F
# 8 .	 23FuckingShitflakes
# 9 .	 Swifties of Dartmouth
# 10 .	 Within
# 11 .	 Ledyard Leaders
# 12 .	 Nu Pingus Personnel
# 13 .	 Dartmouth Billiards Student Organization
# 14 .	 Fahey McClane Floor 3 (23F)
# 15 .	 23F Ledyard Leaders in Training
# 16 .	 Chabad 22-23
# 17 .	 Hillel 22-23
# 18 .	 Led Sub
# 19 .	 WET HOT LEDYARD SUMMER ���☀️
# 20 .	 Tender Love And Care Crew
# 21 .	 People Who Paddle
# 22 .	 Ledyard Racing
# 23 .	 Ledyard IM Basketball
# 24 .	 Ledyard '26s New Member Groupme
# 25 .	 Français 1 Drill (avec Ben)
# 26 .	 west leb 9/09
# 27 .	 Westtown QMUNC
# 28 .	 JHUMUNC
# 29 .	 PMUNC
# Please enter your choice: 1
# Which of the following would you like to enable (Please answer with 'y' or 'n'):
# Obtain Chat History? y
# Obtain Commentor Stats? y
# Obtain all Images? n
# Obtain all Videos? n
#
# Obtained 500 thus far. 2147 remain.
# Obtained 1000 thus far. 1647 remain.
# Obtained 1500 thus far. 1147 remain.
# Obtained 2000 thus far. 647 remain.
# Obtained 2500 thus far. 147 remain.
#
# Beginning to Create Chat Log
# Succesfully Created Chat Log. Refer to Record-points-2023-10-18.html in the Root Directory.
#
# Beginning to Obtain All User Stats
#
# ~~~~~~~~~~~~~~~~~TOTAL COMMENTS~~~~~~~~~~~~~~~
#
# (('� �', 'Daniel Xu'), 288)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 220)
# ('Jeff Walbridge, Jr.', 200)
# (('Rishav', 'Rishav Chakravarty'), 150)
# ('GroupMe', 146)
# ('Ben Sontag', 132)
# ('Dexter Jandres', 108)
# ('Jack Macy', 96)
# ('Tristan Wells', 80)
# ('Benjamin Grayzel', 69)
# ('Jack Van Hooser', 69)
# ('Daniel Hernandez', 60)
# ('Josh Lee', 56)
# ('Jonathan Cartwright', 56)
# ('Brandon', 49)
# ('Dominic Folkes', 48)
# ('Trace Hilbun (he/they)', 42)
# ('Gannon Forsberg', 39)
# ('Agastya Nashier', 35)
# ('Andy Kotz', 35)
# ('Emir Akat', 30)
# ('Harrison Sholler', 30)
# ('Kai Goldstein', 29)
# ('Jason Sinning', 27)
# ('Sebastian Fernandez', 27)
# ('Dan Dong', 24)
# ('Caleb Saks', 24)
# ('Christopher Smith', 24)
# ('Cooper Hyldahl', 23)
# ('Wenhan ☀️', 22)
# ('Jack Sinatra', 22)
# ('Kabir UK The Sequel', 21)
# ('Stephen Veatch', 21)
# ('Anthony Cheng', 20)
# ('Daniel Lubliner', 20)
# ('Garrett Crouch', 17)
# ('Ryan Gonzalez', 17)
# ('Adam Hunt', 14)
# ('Duncan Caramichael', 14)
# ('Trevor Geyer', 14)
# ('Jason Carenz', 14)
# ('Tristan Kunzle', 11)
# ('Ethan Lieberman', 11)
# ('Ben Shaman', 11)
# ('Jaime Graft', 10)
# ('Jack Flaggert', 10)
# ('Paulie Horvath', 10)
# ('Mason Carter', 8)
# ('Tobin Yates', 8)
# ('Jackson Yassin', 8)
# ('Michael Bornstein', 8)
# ('Josh Baxter', 8)
# ('Devin Tsai', 8)
# ('Jesse Chan', 7)
# ('Prescott Herzog', 7)
# ('Rohan Goyal', 7)
# ('Alex Hamel', 7)
# ('jacob gordon', 6)
# ('Paul Cornell', 6)
# ('Jake Zikan', 6)
# ('Leon Wang', 5)
# ('Allan Wang', 5)
# ('Ryker Holsinger', 5)
# ('Wesley Liao', 5)
# ('Olvin Abrego', 4)
# ('Ethan Child', 4)
# ('Sumant Sharma', 3)
# ('Miles', 3)
# ('Shyam Bhagat', 3)
# ('Samuel Dupuis', 3)
# ('Chase Kamikawa', 3)
# ('Zachary Seburn', 3)
# ('Isaac Schildkraut', 3)
# ('Johan', 2)
# ('Gavan Fink', 2)
# ('Hayden Miller', 2)
# ('Justin Chong', 1)
# ('Lucas DiSilvestro', 1)
# ('Angus Yip', 1)
# Total Comments:  2647
#
# ~~~~~~~~~~~~~~~~~TOTAL MENTIONS~~~~~~~~~~~~~~~
#
# Error Logging User: -1
# ('Josh Lee', 181)
# ('Daniel Hernandez', 80)
# ('Brandon', 73)
# ('Agastya Nashier', 64)
# ('Ryan Gonzalez', 61)
# ('Caleb Saks', 57)
# ('Leon Wang', 44)
# ('Garrett Crouch', 43)
# ('Kabir UK The Sequel', 39)
# ('Paulie Horvath', 38)
# ('Jackson Yassin', 35)
# ('jacob gordon', 35)
# ('Cooper Hyldahl', 34)
# ('Ben Shaman', 32)
# ('Tobin Yates', 31)
# ('Rohan Goyal', 31)
# ('Samuel Dupuis', 29)
# ('Emir Akat', 29)
# ('Ethan Child', 28)
# ('Jesse Chan', 27)
# ('Miles', 26)
# ('Trevor Geyer', 24)
# ('Kai Goldstein', 24)
# ('Adam Hunt', 24)
# ('Jack Flaggert', 24)
# ('Ethan Lieberman', 23)
# ('Zachary Seburn', 23)
# ('Chase Kamikawa', 22)
# ('Ryker Holsinger', 20)
# ('Sumant Sharma', 20)
# ('Shyam Bhagat', 19)
# ('Gavan Fink', 14)
# ('Jeff Walbridge, Jr.', 9)
# (('Rishav', 'Rishav Chakravarty'), 9)
# (('� �', 'Daniel Xu'), 8)
# ('Ben Sontag', 7)
# ('Jack Macy', 7)
# ('Christopher Smith', 7)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 6)
# ('Jack Van Hooser', 6)
# ('Jonathan Cartwright', 4)
# ('Dan Dong', 3)
# ('Dexter Jandres', 3)
# ('Jason Carenz', 2)
# ('Sebastian Fernandez', 2)
# ('Benjamin Grayzel', 2)
# ('Daniel Lubliner', 2)
# ('Andy Kotz', 2)
# ('Stephen Veatch', 2)
# ('Harrison Sholler', 1)
# ('Johan', 1)
# ('Mason Carter', 1)
# ('Paul Cornell', 1)
# ('Allan Wang', 1)
# ('Josh Baxter', 1)
# ('Trace Hilbun (he/they)', 1)
# ('Devin Tsai', 1)
# ('Michael Bornstein', 1)
# ('Jack Sinatra', 1)
# Total Mentions:  1345
#
# ~~~~~~~~~~~~~~TOTAL LIKES RECEIVED~~~~~~~~~~~~
#
# (('� �', 'Daniel Xu'), 236)
# ('Jeff Walbridge, Jr.', 192)
# ('Ben Sontag', 169)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 169)
# (('Rishav', 'Rishav Chakravarty'), 146)
# ('Tristan Wells', 123)
# ('Josh Lee', 111)
# ('Brandon', 95)
# ('Dexter Jandres', 94)
# ('Sebastian Fernandez', 91)
# ('Agastya Nashier', 88)
# ('Trevor Geyer', 81)
# ('Dominic Folkes', 72)
# ('Jack Macy', 70)
# ('Jack Van Hooser', 64)
# ('Benjamin Grayzel', 62)
# ('Jonathan Cartwright', 62)
# ('Dan Dong', 59)
# ('Daniel Lubliner', 58)
# ('Ben Shaman', 51)
# ('Andy Kotz', 47)
# ('Jesse Chan', 42)
# ('Jackson Yassin', 40)
# ('Cooper Hyldahl', 40)
# ('Gannon Forsberg', 34)
# ('Christopher Smith', 33)
# ('Jack Sinatra', 33)
# ('Harrison Sholler', 33)
# ('Adam Hunt', 32)
# ('Daniel Hernandez', 30)
# ('Kai Goldstein', 29)
# ('Stephen Veatch', 29)
# ('Jason Carenz', 26)
# ('Jason Sinning', 25)
# ('Ryan Gonzalez', 25)
# ('Trace Hilbun (he/they)', 24)
# ('Tristan Kunzle', 21)
# ('Jack Flaggert', 19)
# ('Zachary Seburn', 19)
# ('GroupMe', 19)
# ('Garrett Crouch', 18)
# ('Wenhan ☀️', 18)
# ('Prescott Herzog', 17)
# ('Ethan Lieberman', 17)
# ('Paul Cornell', 17)
# ('Kabir UK The Sequel', 17)
# ('Jake Zikan', 16)
# ('Michael Bornstein', 16)
# ('Emir Akat', 16)
# ('jacob gordon', 15)
# ('Duncan Caramichael', 13)
# ('Tobin Yates', 12)
# ('Samuel Dupuis', 10)
# ('Jaime Graft', 9)
# ('Josh Baxter', 8)
# ('Miles', 7)
# ('Paulie Horvath', 7)
# ('Ryker Holsinger', 7)
# ('Wesley Liao', 7)
# ('Caleb Saks', 7)
# ('Olvin Abrego', 7)
# ('Mason Carter', 6)
# ('Shyam Bhagat', 6)
# ('Anthony Cheng', 5)
# ('Rohan Goyal', 5)
# ('Alex Hamel', 5)
# ('Lucas DiSilvestro', 4)
# ('Chase Kamikawa', 4)
# ('Angus Yip', 3)
# ('Leon Wang', 3)
# ('Hayden Miller', 3)
# ('Devin Tsai', 3)
# ('Ethan Child', 3)
# ('Isaac Schildkraut', 2)
# ('Johan', 1)
# ('Justin Chong', 1)
# ('Gavan Fink', 1)
# ('Allan Wang', 1)
# ('Sumant Sharma', 0)
# Total Likes:  3010
#
# ~~~~~~~~~~~~~~~TOTAL LIKES GIVEN~~~~~~~~~~~~~~
#
# (('Rishav', 'Rishav Chakravarty'), 333)
# ('Jack Macy', 184)
# ('Daniel Hernandez', 154)
# ('Sebastian Fernandez', 153)
# (('� �', 'Daniel Xu'), 146)
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 134)
# ('Tristan Wells', 111)
# ('Andy Kotz', 82)
# ('Jesse Chan', 79)
# ('Caleb Saks', 77)
# ('Agastya Nashier', 73)
# ('Garrett Crouch', 72)
# ('Ben Sontag', 72)
# ('Stephen Veatch', 65)
# ('Kabir UK The Sequel', 62)
# ('Josh Lee', 59)
# ('Gannon Forsberg', 54)
# ('Brandon', 52)
# ('Shyam Bhagat', 50)
# ('Jack Van Hooser', 50)
# ('Samuel Dupuis', 47)
# ('Benjamin Grayzel', 46)
# ('Jonathan Cartwright', 46)
# ('Ethan Lieberman', 38)
# ('Trace Hilbun (he/they)', 37)
# ('Leon Wang', 37)
# ('Ethan Child', 36)
# ('Duncan Caramichael', 34)
# ('Sumant Sharma', 34)
# ('Jason Carenz', 31)
# ('jacob gordon', 31)
# ('Harrison Sholler', 27)
# ('Zachary Seburn', 26)
# ('Cooper Hyldahl', 26)
# ('Jeff Walbridge, Jr.', 24)
# ('Ryan Gonzalez', 23)
# ('Wenhan ☀️', 23)
# ('Dominic Folkes', 21)
# ('Jack Flaggert', 20)
# ('Trevor Geyer', 20)
# ('Rohan Goyal', 20)
# ('Michael Bornstein', 19)
# ('Paulie Horvath', 18)
# ('Jack Sinatra', 18)
# ('Christopher Smith', 18)
# ('Chase Kamikawa', 16)
# ('Krishnachandra Nair', 13)
# ('Emir Akat', 13)
# ('Dan Dong', 13)
# ('Jaime Graft', 12)
# ('Ryker Holsinger', 11)
# ('Ben Shaman', 11)
# ('Adam Hunt', 10)
# ('Dexter Jandres', 10)
# ('Alex Hamel', 10)
# ('Gavan Fink', 10)
# ('Tristan Kunzle', 9)
# ('Miles', 9)
# ('Jake Zikan', 9)
# ('Kai Goldstein', 9)
# ('Prescott Herzog', 8)
# ('Paul Cornell', 7)
# ('Olvin Abrego', 7)
# ('Josh Baxter', 6)
# ('Tobin Yates', 6)
# ('Jackson Yassin', 6)
# ('Mason Carter', 4)
# ('Angus Yip', 4)
# ('Jason Sinning', 4)
# ('Daniel Lubliner', 3)
# ('Justin Chong', 2)
# ('Noah da Silva', 2)
# ('Hayden Miller', 2)
# ('Isaac Schildkraut', 1)
# ('Allan Wang', 1)
# Total Likes Given:  3010
#
# ~~~~~~~~~~~~~~~~TOTAL SELF LIKES~~~~~~~~~~~~~~
#
# (('Syed Hussaini', 'THE FEDERAL RESERVE BIATCH'), 2)
# ('Sebastian Fernandez', 2)
# ('Andy Kotz', 1)
# ('Agastya Nashier', 1)
# Total Self Likes Given:  6
#
# Finished Displaying All User Stats
#
# Thank you for using GroupMe Stats!

# %%
## Analysis
# brothers = ["Jonathan Cartwright",
#            "Andy Kotz",
#            "Daniel Xu",
#            "Jason Sinning",
#            "Alex Hamel",
#            "Anthony Cheng",
#            "Ben Sontag",
#            "Benjamin Grayzel",
#            "Christopher Smith",
#            "Dan Dong",
#            "Daniel Lubliner",
#            "Devin Tsai",
#            "Dexter Jandres",
#            "Dominic Folkes",
#            "Harrison Sholler",
#            "Hayden Miller",
#            "Isaac Schildkraut",
#            "Jack Macy",
#            "Jack Sinatra",
#            "Jack Van Hooser",
#            "Jake Zikan",
#            "Jason Carenz",
#            "Jeff Walbridge, Jr.",
#            "Josh Baxter",
#            "Krishnachandra Nair",
#            "Michael Bornstein",
#            "Olvin Abrego",
#            "Paul Cornell",
#            "Rishav Chakravarty",
#            "Sebastian Fernandez",
#            "Stephen Veatch",
#            "Syed Hussaini",
#            "Tristan Kunzle",
#            "Tristan Wells",
#            "Wenhan ☀️",
#            "Wesley Liao",
#            "james mosley",
#            "Angus Yip",
#            "Gannon Forsberg"]

df = pd.read_html("Record-points-2023-10-18.html")
df = pd.DataFrame(df[0])
df = df.drop(columns = "Date")


## Filter to relevant messages
filt = df[df["Message"].str.contains(r"(\+\d+|\-\d+)\s\@(\S+\s?[A-Z]?)") &  
          ~df["Message"].str.contains(r"\@Ben\sSontag", na = False)]


regex = r"\@(\S+\s?[A-Z]?)"

mentions = [re.findall(regex, x) for x in filt.Message]
for lst in range(len(mentions)):
    for seq in range(len(mentions[lst])):
        mentions[lst][seq] = mentions[lst][seq].strip()


filt["mention"] = mentions
filt

regex2 = r"\+\d+|\-\d+"
points = [re.findall(regex2, x) for x in filt.Message]
points

filt["points"] = points

people = [len(x) for x in filt.mention]
points_prob = [len(x) for x in filt.points]

filt["people"] = people
filt["points_prob"] = points_prob

problem_cases = filt[(filt["people"] != 1) | (filt["points_prob"] != 1)]

points_as_numbers = [int(x[0]) for x in filt.points]

filt["points_as_numbers"] = points_as_numbers
filt = filt[(filt["points_as_numbers"] <= 10000) & (filt["points_as_numbers"] >= -10000)]

filt = filt.explode("mention")
by_person_sender = filt.groupby("mention")[["points_as_numbers", "Sender"]].agg(sum)
by_person = filt.groupby("mention")["points_as_numbers"].agg(sum)
# Out:
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:48: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   filt = df[df["Message"].str.contains(r"(\+\d+|\-\d+)\s\@(\S+\s?[A-Z]?)") &
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["mention"] = mentions
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points"] = points
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["people"] = people
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points_prob"] = points_prob
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filt["points_as_numbers"] = points_as_numbers
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:83: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   by_person_sender = filt.groupby("mention")[["points_as_numbers", "Sender"]].agg(sum)
# /var/folders/ln/5qs2pl3j2rq28m5qvnj5rj_m0000gn/T/ipykernel_91535/1548943348.py:84: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   by_person = filt.groupby("mention")["points_as_numbers"].agg(sum)

# %%
irrelevant = ["Rishav C",
             "Jonathan C",
             "Jeff W",
             "Jack V",
             "s",
             "Andy K",
             "Syed H",
             "Daniel X",
             "Stephen V",
             "josh",
             "Jack M",
             "dartmouth",
             "ï¿½",
             "ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½ï¿½",
             "josh L",
             "Trace H",
             "Dan D",
             "dexter,",
             "shitflakes",
             "Josh B",
             "Dexter J",
             "Miles M",
             "Benjamin G",
             "Allan W",
             "Daniel L",
             "pledges",
             "Sebastian F",
             "Brandon I",
             "Christopher S",
             "Paul C",
             "Johan"]

by_person = by_person.reset_index()
by_person = by_person[~by_person["mention"].isin(irrelevant)].sort_values(by = "points_as_numbers")
by_person
# Out:
#       mention  points_as_numbers
# 32     Josh L             -13466
# 1   Agastya N               -960
# 41    Rohan G               -749
# 6     Brandon               -705
# 35     Leon W               -627
# 20  Garrett C               -282
# 48   Sumant S               -275
# 17     Emir A               -210
# 13   Daniel H               -208
# 46    Shyam B               -110
# 34      Kai G                -28
# 26    Jason C                -15
# 18    Ethan C                 -5
# 36      Miles                 59
# 50    Tobin Y                350
# 9     Chase K                687
# 44   Samuel D                777
# 52   Trevor G                805
# 8     Caleb S                829
# 0      Adam H                910
# 22     Jack F                957
# 11   Cooper H                983
# 43    Ryker H               1005
# 28    Jesse C               1031
# 55      jacob               1094
# 4       Ben S               1180
# 33    Kabir U               1209
# 19    Ethan L               1401
# 25  Jackson Y               1422
# 53  Zachary S               1434
# 39   Paulie H               1750
# 21    Gavan F               2040
# 42     Ryan G               2052
